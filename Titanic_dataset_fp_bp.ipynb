# %% [markdown]
# <a href="https://colab.research.google.com/github/arthireddy14/Titanic_ann_cloud_deployment/blob/main/Titanic_dataset_fp_bp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data set link: https://drive.google.com/file/d/1IWzu-P3JDlJ6PxlvTDJEEcw220AwIPXE/view?usp=sharing
#
# Problem Statement
# A shipping company wants to build an AI model that predicts whether a passenger would survive or not during an emergency situation based on passenger information.
#
# You are asked to manually perform:
# Forward Propagation
# Error Calculation
# Backpropagation
# Weight Updates
#
# for ONE training record from the Titanic dataset.
#
# Selected Features
# Use the following features from the dataset:
# Feature	Value
# Passenger Class (Pclass)	1
# Age	24
# Fare	120
# Target Output:
# Survived
# 1
#
# Data Preprocessing
# Normalize the inputs using Min-Max Scaling.
# Assume normalized values are:
# Feature	Normalized Value
# Pclass	0.2
# Age	0.24
# Fare	0.80
#
# Neural Network Architecture
# Create a neural network with:
# 3 Input Neurons
# 2 Hidden Neurons
# 1 Output Neuron
#
# Use:
# Sigmoid Activation Function
# Learning Rate = 0.1
# Initial Weights
# Input Layer → Hidden Layer
#
# Connection	Weight
# x1 → h1	0.11
# x2 → h1	0.14
# x3 → h1	0.17
# x1 → h2	0.21
# x2 → h2	0.24
# x3 → h2	0.27
#
# Hidden Layer Biases
# Neuron	Bias
# h1	0.1
# h2	0.1
#
# Hidden Layer → Output Layer
# Connection	Weight
# h1 → o1	0.31
# h2 → o1	0.34
# Output Bias
# bo=0.1b_o = 0.1bo=0.1
#
# Tasks
#
# Task 1
# Calculate the net input for:
# Hidden Neuron h1
# Hidden Neuron h2
#
# Task 2
# Apply sigmoid activation and calculate:
# Output of h1
# Output of h2
#
# Task 3
# Calculate:
# Net input at output neuron
# Final predicted output
#
# Task 4
# Calculate the prediction error using Mean Squared Error.
#
# Task 5
# Perform Backpropagation:
# Calculate output layer gradients
# Calculate hidden layer gradients
#
# Task 6
# Update:
# Hidden → Output weights
# Input → Hidden weights
# Bias values
# using Gradient Descent.

# %%
import numpy as np

# %% [markdown]
# Forward Propagation

# %%
x1=0.2
x2=0.24
x3=0.80
w1=0.11
w2=0.14
w3=0.17
w4=0.21
w5=0.24
w6=0.27

# %%
b1=0.1
b2=0.1
w7=0.31
w8=0.34
b3=0.1

# %%
y=1
n=0.1

# %%
net_h1=w1*x1+w2*x2+w3*x3+b1
net_h2=w4*x1+w5*x2+w6*x3+b2

# %%
print(net_h1)
print(net_h2)
# Out:
# 0.2916
# 0.41559999999999997

# %%
def activation_fn(x):
  return 1/(1+np.exp(-x))

# %%
h1=activation_fn(net_h1)
h2=activation_fn(net_h2)
print(h1)
print(h2)
# Out:
# 0.5723877942219555
# 0.6024298905871749

# %%
net_o1=h1*w7+h2*w8+b3
print(net_o1)
# Out:
# 0.4822663790084457

# %%
o1=activation_fn(net_o1)
print(o1)
# Out:
# 0.6182829041613944

# %% [markdown]
# Error calculation-MSE

# %%
e=0.5*(y-o1)*(y-o1)
print(e)
# Out:
# 0.0728539706277296

# %% [markdown]
# Backward propagation

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# df=pd.read_csv("Titanic-Dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('Titanic-Dataset.csv')
print(df.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-605ccd73-620c-48e1-964d-7082a0945df3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-605ccd73-620c-48e1-964d-7082a0945df3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
x=df[['Pclass','Age','Fare']]
y=df['Survived']

# %%
x['Age'].fillna(x['Age'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_3409/3679931963.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x['Age'].fillna(x['Age'].mean(),inplace=True)
# /tmp/ipykernel_3409/3679931963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Age'].fillna(x['Age'].mean(),inplace=True)

# %%
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %%
model = Sequential([
    Dense(2, activation='sigmoid', input_shape=(3,)),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    x_train,
    y_train,
    epochs=100,
    batch_size=16
)
# Out:
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6699 - loss: 0.6543
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6728 - loss: 0.6476
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6728 - loss: 0.6426
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6699 - loss: 0.6394
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6503 - loss: 0.6373
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6348 - loss: 0.6357
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6362 - loss: 0.6345
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6348 - loss: 0.6335
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6320 - loss: 0.6326
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6306 - loss: 0.6317
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6306 - loss: 0.6311
# Epoch 12/100
# ...

# %%
model.save("titanic_ann_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# Deployment Tasks
#
# Task 1 — Save the Trained Model
# After training the TensorFlow model in Google Colab:
# Requirements
# Save the trained ANN model
# Export the model file
# Download the saved model to your local system
#
# Task 2 — Create Streamlit Application
# Create a Streamlit application named:
# app.py
#
# Task 3 — Design the Web Application
# The webpage must contain the following sections:
# SECTION 1 — Header Area
# Display:
# Project Title
# Subtitle
# AI-related icon/image
# Example Content
# Titanic Survival Prediction System
# “Deep Learning Based Passenger Survival Prediction”
# SECTION 2 — Project Description
# Display a short description explaining:
# purpose of the application
# usage of ANN
# TensorFlow model deployment
# SECTION 3 — Passenger Input Form
# Create input components for:
# Input Field	UI Component
# Passenger Class	Dropdown
# Age	Slider
# Fare	Number Input
# SECTION 4 — Prediction Button
# Add:
# Predict Survival
# When the button is clicked:
# model prediction should execute
# output should be displayed
# SECTION 5 — Prediction Output Area
# Display:
# prediction result
# survival probability
# confidence score
# SECTION 6 — Visualization Area
# Display:
# bar chart OR
# probability meter OR
# pie chart
# to visualize:
# survival probability
# non-survival probability
#
# Task 4 — Data Preprocessing
# Before prediction:
# normalize user inputs
# apply same preprocessing used during training
#
# Task 5 — Load Trained Model
# Inside Streamlit:
# load saved TensorFlow/Keras model
# perform inference on user input
#
# Task 6 — Prediction Logic
# If prediction value:
# greater than 0.5 → Survived
# less than 0.5 → Not Survived
# Display results clearly.
#
# Task 7 — UI Styling Requirements
# Students must design the webpage professionally using:
# columns
# containers
# colors
# markdown
# metrics/cards
#
# Task 8 — Run the Application Locally
# Students must:
# install Streamlit
# run the application locally
# test multiple inputs
#
# Task 9 — Deploy the Application
# Deploy the Streamlit application using:
# Streamlit Community Cloud
